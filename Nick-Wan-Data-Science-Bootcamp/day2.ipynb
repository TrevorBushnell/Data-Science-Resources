# %% [markdown]
# # Nick Wan Data Science Bootcamp Day 2
#
# The second day of notes for the Nick Wan data science bootcamp

# %% [markdown]
# ## Read in the Data and Initialize Packages

# %%
import pandas as pd

df = pd.read_csv('data/2023-nwbc-reds.csv')
df.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF  2022-10-05           93.8           2.39           5.44
# 1         FF  2022-10-05           93.3           2.30           5.51
# 2         SL  2022-10-05           84.3           2.45           5.21
# 3         FF  2022-10-05           93.8           2.32           5.48
# 4         FF  2022-10-05           94.1           2.34           5.54
#
#       pitcher_name  batter  pitcher     events      description  ...  \
# 0  Hughes, Brandon  605244   676714  field_out    hit_into_play  ...
# 1  Hughes, Brandon  605244   676714        NaN             ball  ...
# 2  Hughes, Brandon  605244   676714        NaN             ball  ...
# 3  Hughes, Brandon  605244   676714        NaN    called_strike  ...
# 4  Hughes, Brandon  605244   676714        NaN  swinging_strike  ...
#
#    delta_home_win_exp  delta_run_exp  attack_zone  swing     batter_name  \
# ...

# %% [markdown]
# ## And and Or Statements in Python
#
# * To check if two conditions are true, use an AND statement with the `&` symbol
# * To check if either of two conditions are true, use an OR statement with the `|` symbol

# %% [markdown]
# * Find the rows where the home team is CIN and it is the top of the inning

# %%
df.loc[(df['home_team']=='CIN') & (df['inning_topbot']=='Top')].head()
# Out:
#    pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 13         FF  2022-10-05           95.5          -2.74           6.08
# 14         FF  2022-10-05           94.2          -2.82           6.05
# 15         FF  2022-10-05           94.3          -3.04           5.84
# 16         FC  2022-10-05           88.1          -3.07           5.74
# 17         FF  2022-10-05           95.3          -3.00           5.86
#
#           pitcher_name  batter  pitcher     events    description  ...  \
# 13  Strickland, Hunter  621550   519326  field_out  hit_into_play  ...
# 14  Strickland, Hunter  663845   519326  strikeout  called_strike  ...
# 15  Strickland, Hunter  663845   519326        NaN           ball  ...
# 16  Strickland, Hunter  663845   519326        NaN           foul  ...
# 17  Strickland, Hunter  663845   519326        NaN           ball  ...
#
#     delta_home_win_exp  delta_run_exp  attack_zone  swing      batter_name  \
# ...

# %% [markdown]
# * Create a new column called `is_reds_pitcher` where the home team is CIN and it is the top of the inning OR the away team is CIN and it is the bottom of the inning

# %%
df['is_reds_pitcher'] = 0
df.loc[((df['home_team']=='CIN') & (df['inning_topbot']=='Top')) | (df['away_team']=='CIN') & (df['inning_topbot']=='Bot'), 'is_reds_pitcher'] = 1
df.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF  2022-10-05           93.8           2.39           5.44
# 1         FF  2022-10-05           93.3           2.30           5.51
# 2         SL  2022-10-05           84.3           2.45           5.21
# 3         FF  2022-10-05           93.8           2.32           5.48
# 4         FF  2022-10-05           94.1           2.34           5.54
#
#       pitcher_name  batter  pitcher     events      description  ...  \
# 0  Hughes, Brandon  605244   676714  field_out    hit_into_play  ...
# 1  Hughes, Brandon  605244   676714        NaN             ball  ...
# 2  Hughes, Brandon  605244   676714        NaN             ball  ...
# 3  Hughes, Brandon  605244   676714        NaN    called_strike  ...
# 4  Hughes, Brandon  605244   676714        NaN  swinging_strike  ...
#
#    delta_run_exp  attack_zone  swing     batter_name  total_score is_strike  \
# ...

# %% [markdown]
# ## Some Nice Python Shorthand
#
# * If you want to get everything (either all rows or all columns), then use `:`
# * If you want to get specific columns, put the column names into a list
#
# EX: Get all the rows from your dataframe with only the pitcher name, pitch name, and whether the pitch was a strike columns

# %%
df.loc[:, ['pitcher_name', 'pitch_name', 'is_strike']].head()
# Out:
#       pitcher_name       pitch_name  is_strike
# 0  Hughes, Brandon  4-Seam Fastball          0
# 1  Hughes, Brandon  4-Seam Fastball          0
# 2  Hughes, Brandon           Slider          0
# 3  Hughes, Brandon  4-Seam Fastball          1
# 4  Hughes, Brandon  4-Seam Fastball          1

# %% [markdown]
# ## Pivot Tables in Python
#
# * We can create pivot tables from our pandas DataFrames using the `groupby()` function
# * The result of this is NOT a dataframe... so if you want some aggragation functions just tack them on to the end with normal function notation

# %%
df.loc[df['is_reds_pitcher']==1, ['pitcher_name', 'pitch_name', 'is_strike']].groupby(['pitcher_name', 'pitch_name'], as_index=False).mean()
# Out:
#         pitcher_name       pitch_name  is_strike
# 0    Anderson, Chase  4-Seam Fastball   0.437500
# 1    Anderson, Chase         Changeup   0.542857
# 2    Anderson, Chase        Curveball   0.368421
# 3    Anderson, Chase           Cutter   0.438202
# 4    Anderson, Chase           Sinker   0.464286
# ..               ...              ...        ...
# 141      Zeuch, T.J.           Slider   0.373134
# 142     Zimmer, Kyle  4-Seam Fastball   0.400000
# 143     Zimmer, Kyle         Changeup   1.000000
# 144     Zimmer, Kyle        Curveball   1.000000
# 145     Zimmer, Kyle           Slider   1.000000
#
# [146 rows x 3 columns]

# %%
# write our work to a csv so we can use it later
df.to_csv('./data/2023-nwbc-reds.csv', index=False)
